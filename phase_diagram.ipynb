# %%
import os, sys 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pymatgen.analysis.phase_diagram import PDPlotter, PhaseDiagram, PDEntry, Composition, Element
from thermopot import materials, calculations, reactions, potentials

# %%
os.path
# Out:
# <module 'posixpath' from '/Users/w21013885/miniconda3/lib/python3.9/posixpath.py'>

# %%
path_to = "/Users/w21013885/ThermoPot/BaZrS3/"
os.chdir(path_to)
os.path
# Out:
# <module 'posixpath' from '/Users/w21013885/miniconda3/lib/python3.9/posixpath.py'>

# %%
BaS_calc =  calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/BaS_Fm-3m/scan/aims.out")
BaS2_calc = calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/BaS2_C2_c/scan/aims.out")
BaS3_calc = calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/BaS3_P-421m/scan/aims.out")
BaS3_P21212_calc = calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/BaS3_P2_12_12/scan/aims.out")
Ba2S3_calc = calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/Ba2S3_I4_1md/scan/aims.out")
Ba_calc =   calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/elemental/Ba_Im-3m/scan/aims.out")
S_calc =    calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/elemental/S_P2_c/scan/aims.out")


BaS_material  = materials.Solid("BaS",{"Ba":1, "S":1}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/BaS_Fm-3m.dat", calculation=BaS_calc)
BaS2_material = materials.Solid("BaS2",{"Ba":1, "S":2}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/BaS2_C2_c.dat", calculation=BaS2_calc)
BaS3_material = materials.Solid("BaS3",{"Ba":1, "S":3}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/BaS3_P-421m.dat", calculation=BaS3_calc)
BaS3_P21212_material = materials.Solid("BaS3",{"Ba":1, "S":3}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/BaS3_P2_12_12.dat", calculation=BaS3_P21212_calc)
Ba2S3_material = materials.Solid("Ba2S3",{"Ba":2, "S":3}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/Ba2S3_I4_1md.dat", calculation=Ba2S3_calc) 
Ba_material   = materials.Solid("Ba",{"Ba":1}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/Ba_Im-3m.dat", calculation=Ba_calc)
S_material    = materials.Solid("S",{"S":1}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/S_P2_c.dat", calculation=S_calc)

# %%
T=1200
P=1
Ba = PDEntry(Composition("Ba"), Ba_material.mu(T,P,xc='scan'))
S  = PDEntry(Composition("S"), S_material.mu(T,P,xc='scan'))
BaS = PDEntry(Composition("BaS"), BaS_material.mu(T,P,xc='scan'))
BaS2 = PDEntry(Composition("BaS2"), BaS2_material.mu(T,P,xc='scan'))
BaS3 = PDEntry(Composition("BaS3"), BaS3_material.mu(T,P,xc='scan'))
BaS3_P21212 = PDEntry(Composition("BaS3"), BaS3_P21212_material.mu(T,P,xc='scan'))
Ba2S3 = PDEntry(Composition("Ba2S3"), Ba2S3_material.mu(T,P,xc='scan'))
print(Ba)
# Out:
# PDEntry : Ba1 with energy = -225173.0953

# %%
pd = PhaseDiagram([BaS,BaS3,BaS2,Ba2S3,BaS3_P21212,Ba,S])
plotter = PDPlotter(pd, show_unstable=1, backend="matplotlib")
plotter.get_plot()
# Out:
# <module 'matplotlib.pyplot' from '/Users/w21013885/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
ZrS2_calc =  calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/ZrS2_P-3m1/scan/aims.out")
Zr3S4_calc = calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/Zr3S4_Fd-3m/scan/aims.out")
ZrS3_calc = calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/ZrS3_P2_1m/scan/aims.out")
ZrS_cub_calc =   calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/ZrS_Fm-3m/scan/aims.out")
ZrS_tet_calc =    calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/binary/ZrS_P4_nmm/scan/aims.out")
Zr_calc =    calculations.AimsCalculation("../../../../../../../Users/w21013885/ThermoPot/BaZrS3/raw_aims_files/elemental/Zr_P63_mmc/scan/aims.out")

ZrS2_material  = materials.Solid("ZrS2",{"Zr":1, "S":2}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/ZrS2_P-3m1.dat", calculation=ZrS2_calc)
Zr3S4_material = materials.Solid("Zr3S4",{"Zr":3, "S":4}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/Zr3S4_Fd-3m.dat", calculation=Zr3S4_calc)
ZrS3_material = materials.Solid("ZrS3",{"Zr":1, "S":3}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/ZrS3_P2_1m.dat", calculation=ZrS3_calc)                    
ZrS_cub_material   = materials.Solid("ZrS",{"Zr":1,"S":1}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/ZrS_Fm-3m.dat", calculation=ZrS_cub_calc)
ZrS_tet_material    = materials.Solid("ZrS",{"Zr":1,"S":1}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/ZrS_P4_nmm.dat", calculation=ZrS_tet_calc)                               
Zr_material    = materials.Solid("Zr",{"Zr":1}, "../../../../../../../Users/w21013885/ThermoPot/BaZrS3/phonopy_output/Zr_P63_mmc.dat", calculation=Zr_calc)

# %%
T=1200
P=1
Zr = PDEntry(Composition("Zr"), Zr_material.mu(T,P,xc='scan'))
ZrS2  = PDEntry(Composition("ZrS2"), ZrS2_material.mu(T,P,xc='scan'))
Zr3S4 = PDEntry(Composition("Zr3S4"), Zr3S4_material.mu(T,P,xc='scan'))
ZrS3 = PDEntry(Composition("ZrS3"), ZrS3_material.mu(T,P,xc='scan'))
ZrS_cub = PDEntry(Composition("ZrS"), ZrS_cub_material.mu(T,P,xc='scan'))
ZrS_tet = PDEntry(Composition("ZrS"), ZrS_tet_material.mu(T,P,xc='scan'))

# %%
pd = PhaseDiagram([ZrS2,Zr3S4,ZrS3,ZrS_cub,ZrS_tet,Zr,S])
plotter = PDPlotter(pd, show_unstable=1, backend="matplotlib")
plotter.get_plot()
# Out:
# <module 'matplotlib.pyplot' from '/Users/w21013885/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>
